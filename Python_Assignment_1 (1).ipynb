# %% [markdown]
# # Python Assignment 1
#
# **Topics:** Comments, Variables, Data Types, Type Conversion, Slicing and Boolean Values

# %% [markdown]
# ## Q1. How do you comment code in Python? What are the different types of comments?

# %%
# Single-line comment
print("Hello")

# Multi-line comment
'''
This is a
multi-line comment
'''
print("Python comments")
# Out:
# Hello
# Python comments

# %% [markdown]
# ## Q2. What are variables in Python? How do you declare and assign values to variables?

# %%
name = "Ranjeet Singh"
age = 25
price = 99.99

print(name)
print(age)
print(price)
# Out:
# Ranjeet Singh
# 25
# 99.99

# %% [markdown]
# ## Q3. How do you convert one data type to another in Python?

# %%
x = "25"

integer_value = int(x)
float_value = float(x)
string_value = str(integer_value)

print(integer_value)
print(float_value)
print(string_value)
# Out:
# 25
# 25.0
# 25

# %% [markdown]
# ## Q4. How do you write and execute a Python script from the command line?

# %%
# Save this code in a file named hello.py:
# print("Hello, Python!")
#
# Then execute it from the command line using:
# python hello.py

# %% [markdown]
# ## Q5. Given a list my_list = [1, 2, 3, 4, 5], write the code to slice the list and obtain [2, 3].

# %%
my_list = [1, 2, 3, 4, 5]

result = my_list[1:3]

print(result)
# Out:
# [2, 3]

# %% [markdown]
# ## Q6. What is a complex number in mathematics, and how is it represented in Python?

# %%
z = 3 + 4j

print(z)
print(type(z))
# Out:
# (3+4j)
# <class 'complex'>

# %% [markdown]
# ## Q7. What is the correct way to declare a variable named age and assign the value 25 to it?

# %%
age = 25

print(age)
# Out:
# 25

# %% [markdown]
# ## Q8. Declare a variable named price and assign the value 9.99 to it. What data type does this variable belong to?

# %%
price = 9.99

print(price)
print(type(price))
# Out:
# 9.99
# <class 'float'>

# %% [markdown]
# ## Q9. Create a variable named name and assign your full name to it as a string. How would you print the value of this variable?

# %%
name = "Ranjeet Singh"

print(name)
# Out:
# Ranjeet Singh

# %% [markdown]
# ## Q10. Given the string "Hello, World!", extract the substring "World".

# %%
text = "Hello, World!"

result = text[7:12]

print(result)
# Out:
# World

# %% [markdown]
# ## Q11. Create a variable named is_student and assign a boolean value indicating whether you are currently a student or not.

# %%
is_student = True

print(is_student)
print(type(is_student))
# Out:
# True
# <class 'bool'>
